# %% [markdown]
# # Pandas Practice

# %% [markdown]
# This exercise notebook is taken from:
# https://github.com/mrdbourke/zero-to-mastery-ml/blob/master/section-2-data-science-and-ml-tools/pandas-exercises.ipynb

# %% [markdown]
# ## Car Sales Dataset
#
# https://github.com/mrdbourke/zero-to-mastery-ml/tree/master/data

# %% [markdown]
# ### 1. Problem
#
# 1. Practice Pandas using the car-sales.csv data set
# 2. Learn to deal with missing data founs in car-sales-missing.csv dataset
# 3. Use matplotlib to plot values from the car-sales dataset
# 4. Manipulation of data

# %%
# import pandas
import pandas as pd

# %%
# create a series of three different colors
colors = pd.Series(["Yellow", "Purple", "Blue"])
# view the series
colors
# Out:
# 0    Yellow
# 1    Purple
# 2      Blue
# dtype: object

# %%
# create a series of three different car types and view it
car_type = pd.Series(["Jeep", "Sedan", "SUV"])
car_type
# Out:
# 0     Jeep
# 1    Sedan
# 2      SUV
# dtype: object

# %%
# combine series to data frame
df = pd.concat([colors, car_type], axis = 1)
df
# Out:
#         0      1
# 0  Yellow   Jeep
# 1  Purple  Sedan
# 2    Blue    SUV

# %%
# Import "../data/car-sales.csv" and turn it into a DataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Export the DataFrame you created to a .csv file
car_sales.to_csv("car_sales_exported")

# %%
# Find the different datatypes of the car data DataFrame
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
# Describe your current car sales DataFrame using describe()
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
# Get information about your DataFrame using info()
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %% [markdown]
# Price is an object and not an integer

# %%
# Create a Series of different numbers and find the mean of them
## Used the number from the Odometer column
car_sales["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
# Create a Series of different numbers and find the sum of them
car_random = pd.Series([3,5,5,6,8,9])
car_random.sum()
# Out:
# 36

# %%
# List out all the column names of the car sales DataFrame
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
# Find the length of the car sales DataFrame
len(car_sales)
# Out:
# 10

# %%
# Show the first 5 rows of the car sales DataFrame
car_sales.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# Show the first 7 rows of the car sales DataFrame
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
# Show the bottom 5 rows of the car sales DataFrame
car_sales.tail(5)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# Use .loc to select the row at index 3 of the car sales DataFrame
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# Use .iloc to select the row at position 3 of the car sales DataFrame
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %% [markdown]
# .loc[] is primarily label based, but may also be used with a boolean array.
# .iloc[] is primarily integer position based (from 0 to length-1 of the axis),
#     but may also be used with a boolean array.

# %%
# Select the "Odometer (KM)" column from the car sales DataFrame
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# Find the mean of the "Odometer (KM)" column in the car sales DataFrame
car_sales["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
# Select the rows with over 100,000 kilometers on the Odometer
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
# Create a crosstab of the Make and Doors columns
cross_tab = pd.crosstab(car_sales["Make"], car_sales["Doors"])
cross_tab
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Group columns of the car sales DataFrame by the Make column and find the average
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# Import Matplotlib and create a plot of the Odometer column
# Don't forget to use %matplotlib inline

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Create a histogram of the Odometer column using hist()
car_sales["Odometer (KM)"].hist(color = "purple")

# %%
# Try to plot the Price column using plot()
    ## Since Price is O, need to convert to int
# Remove the punctuation from price column
# Change the datatype of the Price column to integers
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]' ,'').astype(int)

# %%
# Remove the two extra zeros at the end of the price column
car_sales["Price"] = car_sales["Price"]/10

# Check the changes to the price column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price
# 0  Toyota  White         150043      4   40000.0
# 1   Honda    Red          87899      4   50000.0
# 2  Toyota   Blue          32549      3   70000.0
# 3     BMW  Black          11179      5  220000.0
# 4  Nissan  White         213095      4   35000.0
# 5  Toyota  Green          99213      4   45000.0
# 6   Honda   Blue          45698      4   75000.0
# 7   Honda   Blue          54738      4   70000.0
# 8  Toyota  White          60000      4   62500.0
# 9  Nissan  White          31600      4   97000.0

# %%
car_sales["Price"].plot(color = "red")

# %%
# Lower the strings of the Make column
# Make lowering the case of the Make column permanent
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
# Check the car sales DataFrame
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price
# 0  toyota  White         150043      4   40000.0
# 1   honda    Red          87899      4   50000.0
# 2  toyota   Blue          32549      3   70000.0
# 3     bmw  Black          11179      5  220000.0
# 4  nissan  White         213095      4   35000.0
# 5  toyota  Green          99213      4   45000.0
# 6   honda   Blue          45698      4   75000.0
# 7   honda   Blue          54738      4   70000.0
# 8  toyota  White          60000      4   62500.0
# 9  nissan  White          31600      4   97000.0

# %%
# Import the car sales DataFrame with missing data ("../data/car-sales-missing-data.csv")
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# Check out the new DataFrame
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# Fill the Odometer (KM) column missing values with the mean of the column inplace
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace = True)

# %%
# View the car sales missing DataFrame and verify the changes
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# Remove the rest of the missing data inplace
car_sales_miss_drop = car_sales_missing.dropna()

# %%
# Verify the missing values are removed by viewing the DataFrame
car_sales_miss_drop
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %% [markdown]
# Now we will starting columns to the data frame

# %%
# Create a "Seats" column where every row has a value of 5
car_sales["Seats"] = 5
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats
# 0  toyota  White         150043      4   40000.0      5
# 1   honda    Red          87899      4   50000.0      5
# 2  toyota   Blue          32549      3   70000.0      5
# 3     bmw  Black          11179      5  220000.0      5
# 4  nissan  White         213095      4   35000.0      5
# 5  toyota  Green          99213      4   45000.0      5
# 6   honda   Blue          45698      4   75000.0      5
# 7   honda   Blue          54738      4   70000.0      5
# 8  toyota  White          60000      4   62500.0      5
# 9  nissan  White          31600      4   97000.0      5

# %%
# Create a column called "Engine Size" with random values between 1.3 and 4.5
# Remember: If you're doing it from a Python list, the list has to be the same length
# as the DataFrame

car_sales["Engine Size"] = pd.Series([1.3, 1.5, 2.8, 2.3, 2.6, 4.5])
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats  Engine Size
# 0  toyota  White         150043      4   40000.0      5          1.3
# 1   honda    Red          87899      4   50000.0      5          1.5
# 2  toyota   Blue          32549      3   70000.0      5          2.8
# 3     bmw  Black          11179      5  220000.0      5          2.3
# 4  nissan  White         213095      4   35000.0      5          2.6
# 5  toyota  Green          99213      4   45000.0      5          4.5
# 6   honda   Blue          45698      4   75000.0      5          NaN
# 7   honda   Blue          54738      4   70000.0      5          NaN
# 8  toyota  White          60000      4   62500.0      5          NaN
# 9  nissan  White          31600      4   97000.0      5          NaN

# %%
car_sales["Engine Size"] = car_sales["Engine Size"].fillna(car_sales["Engine Size"].mean())
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats  Engine Size
# 0  toyota  White         150043      4   40000.0      5          1.3
# 1   honda    Red          87899      4   50000.0      5          1.5
# 2  toyota   Blue          32549      3   70000.0      5          2.8
# 3     bmw  Black          11179      5  220000.0      5          2.3
# 4  nissan  White         213095      4   35000.0      5          2.6
# 5  toyota  Green          99213      4   45000.0      5          4.5
# 6   honda   Blue          45698      4   75000.0      5          2.5
# 7   honda   Blue          54738      4   70000.0      5          2.5
# 8  toyota  White          60000      4   62500.0      5          2.5
# 9  nissan  White          31600      4   97000.0      5          2.5

# %%
# Create a column which represents the price of a car per kilometer
# Then view the DataFrame
car_sales["Price/KM"] = car_sales["Price"] / car_sales["Odometer (KM)"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats  Engine Size  \
# 0  toyota  White         150043      4   40000.0      5          1.3
# 1   honda    Red          87899      4   50000.0      5          1.5
# 2  toyota   Blue          32549      3   70000.0      5          2.8
# 3     bmw  Black          11179      5  220000.0      5          2.3
# 4  nissan  White         213095      4   35000.0      5          2.6
# 5  toyota  Green          99213      4   45000.0      5          4.5
# 6   honda   Blue          45698      4   75000.0      5          2.5
# 7   honda   Blue          54738      4   70000.0      5          2.5
# 8  toyota  White          60000      4   62500.0      5          2.5
# 9  nissan  White          31600      4   97000.0      5          2.5
#
#     Price/KM
# 0   0.266590
# 1   0.568835
# 2   2.150604
# 3  19.679757
# 4   0.164246
# 5   0.453570
# 6   1.641210
# 7   1.278819
# 8   1.041667
# 9   3.069620

# %%
# Remove the last column you added using .drop()
car_sales.drop(["Price/KM"], axis = 1)
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats  Engine Size
# 0  toyota  White         150043      4   40000.0      5          1.3
# 1   honda    Red          87899      4   50000.0      5          1.5
# 2  toyota   Blue          32549      3   70000.0      5          2.8
# 3     bmw  Black          11179      5  220000.0      5          2.3
# 4  nissan  White         213095      4   35000.0      5          2.6
# 5  toyota  Green          99213      4   45000.0      5          4.5
# 6   honda   Blue          45698      4   75000.0      5          2.5
# 7   honda   Blue          54738      4   70000.0      5          2.5
# 8  toyota  White          60000      4   62500.0      5          2.5
# 9  nissan  White          31600      4   97000.0      5          2.5

# %%
# Shuffle the DataFrame using sample() with the frac parameter set to 1
# Save the the shuffled DataFrame to a new variable
car_sales_shuf = car_sales.sample(frac  = 1)
car_sales_shuf
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats  Engine Size  \
# 4  nissan  White         213095      4   35000.0      5          2.6
# 7   honda   Blue          54738      4   70000.0      5          2.5
# 9  nissan  White          31600      4   97000.0      5          2.5
# 0  toyota  White         150043      4   40000.0      5          1.3
# 6   honda   Blue          45698      4   75000.0      5          2.5
# 2  toyota   Blue          32549      3   70000.0      5          2.8
# 3     bmw  Black          11179      5  220000.0      5          2.3
# 5  toyota  Green          99213      4   45000.0      5          4.5
# 8  toyota  White          60000      4   62500.0      5          2.5
# 1   honda    Red          87899      4   50000.0      5          1.5
#
#     Price/KM
# 4   0.164246
# 7   1.278819
# 9   3.069620
# 0   0.266590
# 6   1.641210
# 2   2.150604
# 3  19.679757
# 5   0.453570
# 8   1.041667
# 1   0.568835

# %% [markdown]
# Notice how the index numbers get moved around. The sample() function is a great way to get random samples from your DataFrame. It's also another great way to shuffle the rows by setting frac=1.

# %%
# Reset the indexes of the shuffled DataFrame
car_sales_shuf.reset_index(drop = True, inplace = True)
car_sales_shuf
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats  Engine Size  \
# 0  nissan  White         213095      4   35000.0      5          2.6
# 1   honda   Blue          54738      4   70000.0      5          2.5
# 2  nissan  White          31600      4   97000.0      5          2.5
# 3  toyota  White         150043      4   40000.0      5          1.3
# 4   honda   Blue          45698      4   75000.0      5          2.5
# 5  toyota   Blue          32549      3   70000.0      5          2.8
# 6     bmw  Black          11179      5  220000.0      5          2.3
# 7  toyota  Green          99213      4   45000.0      5          4.5
# 8  toyota  White          60000      4   62500.0      5          2.5
# 9   honda    Red          87899      4   50000.0      5          1.5
#
#     Price/KM
# 0   0.164246
# 1   1.278819
# 2   3.069620
# 3   0.266590
# 4   1.641210
# 5   2.150604
# 6  19.679757
# 7   0.453570
# 8   1.041667
# 9   0.568835

# %% [markdown]
# Notice the index numbers have been changed to have order (start from 0)

# %%
# Change the Odometer values from kilometers to miles using a Lambda function
# Then view the DataFrame
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.609)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats  Engine Size  \
# 0  toyota  White   93252.330640      4   40000.0      5          1.3
# 1   honda    Red   54629.583592      4   50000.0      5          1.5
# 2  toyota   Blue   20229.334991      3   70000.0      5          2.8
# 3     bmw  Black    6947.793661      5  220000.0      5          2.3
# 4  nissan  White  132439.403356      4   35000.0      5          2.6
# 5  toyota  Green   61661.280298      4   45000.0      5          4.5
# 6   honda   Blue   28401.491610      4   75000.0      5          2.5
# 7   honda   Blue   34019.888129      4   70000.0      5          2.5
# 8  toyota  White   37290.242387      4   62500.0      5          2.5
# 9  nissan  White   19639.527657      4   97000.0      5          2.5
#
#     Price/KM
# 0   0.266590
# 1   0.568835
# 2   2.150604
# 3  19.679757
# 4   0.164246
# 5   0.453570
# 6   1.641210
# 7   1.278819
# 8   1.041667
# 9   3.069620

# %%
# Change the title of the Odometer (KM) to represent miles instead of kilometer
car_sales.rename(columns = {"Odometer (KM)": "Odometer Miles"}, inplace = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer Miles  Doors     Price  Seats  Engine Size  \
# 0  toyota  White    93252.330640      4   40000.0      5          1.3
# 1   honda    Red    54629.583592      4   50000.0      5          1.5
# 2  toyota   Blue    20229.334991      3   70000.0      5          2.8
# 3     bmw  Black     6947.793661      5  220000.0      5          2.3
# 4  nissan  White   132439.403356      4   35000.0      5          2.6
# 5  toyota  Green    61661.280298      4   45000.0      5          4.5
# 6   honda   Blue    28401.491610      4   75000.0      5          2.5
# 7   honda   Blue    34019.888129      4   70000.0      5          2.5
# 8  toyota  White    37290.242387      4   62500.0      5          2.5
# 9  nissan  White    19639.527657      4   97000.0      5          2.5
#
#     Price/KM
# 0   0.266590
# 1   0.568835
# 2   2.150604
# 3  19.679757
# 4   0.164246
# 5   0.453570
# 6   1.641210
# 7   1.278819
# 8   1.041667
# 9   3.069620
